# %% [markdown]
# In this notebook we will train a Core/Readout model on data from Hoefling et al., 2024: ["A chromatic feature detector in the retina signals visual context changes"](https://elifesciences.org/articles/86860).
#
# We will closely follow the structure of our unified training script, `openretina.cli.train.py`, including using Hydra to import and examine model config files.
#
# Note that using `openretina.cli.train.py`, and the corresponding command `openretina train` is the recommended way to run model training, as for some configurations it can take some time.

# %% [markdown]
# # Imports

# %%
import logging
import os

import hydra
import lightning
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
from einops import rearrange

from openretina.data_io.base import compute_data_info
from openretina.data_io.cyclers import LongCycler, ShortCycler
from openretina.data_io.hoefling_2024.dataloaders import natmov_dataloaders_v2
from openretina.data_io.hoefling_2024.responses import filter_responses, make_final_responses
from openretina.data_io.hoefling_2024.stimuli import movies_from_pickle
from openretina.eval.metrics import correlation_numpy, feve
from openretina.models.core_readout import CoreReadout
from openretina.utils.file_utils import get_local_file_path
from openretina.utils.h5_handling import load_h5_into_dict
from openretina.utils.misc import CustomPrettyPrinter
from openretina.utils.plotting import (
    numpy_to_mp4_video,
)

matplotlib.rcParams["pdf.fonttype"] = 42
matplotlib.rcParams["ps.fonttype"] = 42

logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)  # to display logs in jupyter

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

pp = CustomPrettyPrinter(indent=4, max_lines=30)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Let's import also the global config file for this model using hydra.

# %%
torch.cuda.empty_cache()

# %%
with hydra.initialize(config_path=os.path.join("..", "configs"), version_base="1.3"):
    cfg = hydra.compose(config_name="hoefling_2024_core_readout_low_res.yaml")

# %% [markdown]
# # Loading data

# %% [markdown]
# The first step in loading data is determining from where it will be fetched / stored.
#
# Let's see how this is handled in the configs:

# %%
pp.pprint(cfg.paths)
# Out:
# {   'cache_dir': '${oc.env:OPENRETINA_CACHE_DIRECTORY}',
#     'data_dir': '${paths.cache_dir}/data/',
#     'load_model_path': None,
#     'log_dir': '.',
#     'movies_path': 'https://huggingface.co/datasets/open-retina/open-retina/blob/main/euler_lab/hoefling_2024/stimuli/rgc_natstim_18x16_joint_normalized_2024-01-11.zip',
#     'output_dir': '${hydra:runtime.output_dir}',
#     'responses_path': 'https://huggingface.co/datasets/open-retina/open-retina/resolve/main/euler_lab/hoefling_2024/responses/rgc_natstim_2024-08-14.zip'}

# %% [markdown]
# The config contains the path from where files will be downloaded, and also requires the `cache_dir` to be set by the user: this is the directory where the data will be stored on download.
#
# When using the training script, if cache_dir is not set by the user in the config files or somewhere in the script, this will fall back to the `OPENRETINA_CACHE_DIRECTORY` environment variable, which by default points to `~/openretina_cache`.
#
# If set, the `cache_dir` is also what the package will use in place of the default openretina cache folder. Let's set both here:

# %%
your_chosen_root_folder = "/home/bethge/bkr618/openretina_cache"  # Change this with your desired path.

cfg.paths.cache_dir = your_chosen_root_folder

# We will also overwrite the output directory for the logs/model to the local folder.
cfg.paths.log_dir = your_chosen_root_folder
cfg.paths.output_dir = your_chosen_root_folder

os.environ["OPENRETINA_CACHE_DIRECTORY"] = your_chosen_root_folder

# %% [markdown]
# ## Stimuli

# %% [markdown]
# Loading of the stimuli is achieved, in the training script, via:
# ```
# movies_dict = hydra.utils.call(cfg.data_io.stimuli)
# ```
#
# Let's unpack it here.

# %%
pp.pprint(cfg.data_io.stimuli)
# Out:
# {   '_convert_': 'object',
#     '_target_': 'openretina.data_io.hoefling_2024.stimuli.movies_from_pickle',
#     'file_path': {   '_convert_': 'object',
#                      '_target_': 'openretina.utils.file_utils.get_local_file_path',
#                      'cache_folder': '${paths.cache_dir}',
#                      'file_path': '${paths.movies_path}'}}

# %% [markdown]
# Essentially, using the `get_local_file_path` function, if `file_path` is not a local fiile, it will be downloaded to the cache folder and read from there.

# %%
movies_path = get_local_file_path(file_path=cfg.paths.movies_path, cache_folder=cfg.paths.data_dir)

movies_dict = movies_from_pickle(movies_path)
# Out:
# 2025-10-23 09:40:08,639 - INFO - Fetching file list for open-retina/open-retina...
# 2025-10-23 09:40:08,823 - INFO - Downloading euler_lab/hoefling_2024/stimuli/rgc_natstim_18x16_joint_normalized_2024-01-11.zip...
# euler_lab/hoefling_2024/stimuli/rgc_nats(…):   0%|          | 0.00/73.7M [00:00<?, ?B/s]
#   2025-10-23T07:40:11.564277Z ERROR  Python exception updating progress:, error: PyErr { type: <class 'LookupError'>, value: LookupError(<ContextVar name='shell_parent' at 0x7f93e6d30860>), traceback: Some(<traceback object at 0x7f92ad1e25c0>) }, caller: "src/progress_update.rs:313"
#     at /home/runner/work/xet-core/xet-core/error_printer/src/lib.rs:28
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.13/site-packages/huggingface_hub/file_download.py:629, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     627     progress.update(progress_bytes)
# --> 629 download_files(
#     630     xet_download_info,
#     631     endpoint=connection_info.endpoint,
#     632     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     633     token_refresher=token_refresher,
#     634     progress_updater=[progress_updater],
#     635 )
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 movies_path = get_local_file_path(file_path=cfg.paths.movies_path, cache_folder=cfg.paths.data_dir)
#       3 movies_dict = movies_from_pickle(movies_path)
#
# File ~/open-retina/openretina/utils/file_utils.py:270, in get_local_file_path(file_path, cache_folder)
#     268 elif file_path.startswith(HUGGINGFACE_BASE_URL):
#     269     target_relative_path = file_path.split("main/")[-1]
# --> 270     return huggingface_download(target_relative_path, Path(cache_folder))
#     272 elif file_path.startswith("https://"):
#     273     raise NotImplementedError(f"Only {GIN_BASE_URL} data storage is supported for now.")
#
# File ~/open-retina/openretina/utils/file_utils.py:242, in huggingface_download(target_name, local_dir, unzip)
#     239 files = api.list_repo_files(HUGGINGFACE_REPO_ID, repo_type="dataset")
#     241 if target_name in files:  # Direct match, download the file
# --> 242     downloaded_file = download_file_from_huggingface(target_name, local_dir, unzip)
#     243     return Path(downloaded_file)
#     244 else:  # Otherwise, assume it's a folder
#
# File ~/open-retina/openretina/utils/file_utils.py:200, in download_file_from_huggingface(file_name, local_dir, unzip)
#     197     return existing_path
#     199 LOGGER.info(f"Downloading {file_name}...")
# --> 200 downloaded_file = hf_hub_download(
#     201     repo_id=HUGGINGFACE_REPO_ID,
#     202     filename=file_name,
#     203     local_dir=local_dir,
#     204     repo_type="dataset",
#     205 )
#     207 if unzip and downloaded_file.endswith(".zip"):
#     208     return unzip_and_cleanup(Path(downloaded_file))
#
# File ~/.local/lib/python3.13/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.13/site-packages/huggingface_hub/file_download.py:990, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     981     if local_dir_use_symlinks != "auto":
#     982         warnings.warn(
#     983             "`local_dir_use_symlinks` parameter is deprecated and will be ignored. "
#     984             "The process to download files to a local folder has been updated and do "
#    (...)    987             "For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder."
#     988         )
# --> 990     return _hf_hub_download_to_local_dir(
#     991         # Destination
#     992         local_dir=local_dir,
#     993         # File info
#     994         repo_id=repo_id,
#     995         repo_type=repo_type,
#     996         filename=filename,
#     997         revision=revision,
#     998         # HTTP info
#     999         endpoint=endpoint,
#    1000         etag_timeout=etag_timeout,
#    1001         headers=hf_headers,
#    1002         proxies=proxies,
#    1003         token=token,
#    1004         # Additional options
#    1005         cache_dir=cache_dir,
#    1006         force_download=force_download,
#    1007         local_files_only=local_files_only,
#    1008     )
#    1009 else:
#    1010     return _hf_hub_download_to_cache_dir(
#    1011         # Destination
#    1012         cache_dir=cache_dir,
#    (...)   1026         force_download=force_download,
#    1027     )
#
# File ~/.local/lib/python3.13/site-packages/huggingface_hub/file_download.py:1300, in _hf_hub_download_to_local_dir(local_dir, repo_id, repo_type, filename, revision, endpoint, etag_timeout, headers, proxies, token, cache_dir, force_download, local_files_only)
#    1298 with WeakFileLock(paths.lock_path):
#    1299     paths.file_path.unlink(missing_ok=True)  # delete outdated file first
# -> 1300     _download_to_tmp_and_move(
#    1301         incomplete_path=paths.incomplete_path(etag),
#    1302         destination_path=paths.file_path,
#    1303         url_to_download=url_to_download,
#    1304         proxies=proxies,
#    1305         headers=headers,
#    1306         expected_size=expected_size,
#    1307         filename=filename,
#    1308         force_download=force_download,
#    1309         etag=etag,
#    1310         xet_file_data=xet_file_data,
#    1311     )
#    1313 write_download_metadata(local_dir=local_dir, filename=filename, commit_hash=commit_hash, etag=etag)
#    1314 return str(paths.file_path)
#
# File ~/.local/lib/python3.13/site-packages/huggingface_hub/file_download.py:1723, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1721 if xet_file_data is not None and is_xet_available():
#    1722     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1723     xet_get(
#    1724         incomplete_path=incomplete_path,
#    1725         xet_file_data=xet_file_data,
#    1726         headers=headers,
#    1727         expected_size=expected_size,
#    1728         displayed_filename=filename,
#    1729     )
#    1730 else:
#    1731     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File ~/.local/lib/python3.13/site-packages/huggingface_hub/file_download.py:624, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     613     displayed_filename = f"{displayed_filename[:40]}(…)"
#     615 progress_cm = _get_progress_bar_context(
#     616     desc=displayed_filename,
#     617     log_level=logger.getEffectiveLevel(),
#    (...)    621     _tqdm_bar=_tqdm_bar,
#     622 )
# --> 624 with progress_cm as progress:
#     626     def progress_updater(progress_bytes: float):
#     627         progress.update(progress_bytes)
#
# File /opt/conda/lib/python3.13/site-packages/tqdm/std.py:1138, in tqdm.__exit__(self, exc_type, exc_value, traceback)
#    1135 def __enter__(self):
#    1136     return self
# -> 1138 def __exit__(self, exc_type, exc_value, traceback):
#    1139     try:
#    1140         self.close()
#
# KeyboardInterrupt:

# %%
cfg.paths.movies_path
# Out:
# 'https://huggingface.co/datasets/open-retina/open-retina/blob/main/euler_lab/hoefling_2024/stimuli/rgc_natstim_18x16_joint_normalized_2024-01-11.zip'

# %%
file_path = '/home/bethge/bkr618/openretina_cache/euler_lab/hoefling_2024/stimuli/rgc_natstim_72x64_joint_normalized_2024-10-11.pkl'
movie_stimuli = movies_from_pickle(file_path)

# %%
numpy_to_mp4_video(movie_stimuli.test_movie, fps=30)
# Out:
# <video controls  width="640"  height="360">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# Let us also visualize a few seconds of the training video:

# %%
numpy_to_mp4_video(movie_stimuli.train[:, :600, ...])
# Out:
# <video controls  width="640"  height="360">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Responses

# %% [markdown]
# In the training script, responses are loaded through:
#
# ```
# neuron_data_dict = hydra.utils.call(cfg.data_io.responses)
# ```
#
# Let's unpack it here.

# %%
pp.pprint(cfg.data_io.responses)
# Out:
# {   '_convert_': 'object',
#     '_target_': 'openretina.data_io.hoefling_2024.responses.make_final_responses',
#     'data_dict': {   '_convert_': 'object',
#                      '_target_': 'openretina.data_io.hoefling_2024.responses.filter_responses',
#                      'all_responses': {   '_convert_': 'object',
#                                           '_target_': 'openretina.utils.h5_handling.load_h5_into_dict',
#                                           'file_path': {   '_convert_': 'object',
#                                                            '_target_': 'openretina.utils.file_utils.get_local_file_path',
#                                                            'cache_folder': '${paths.cache_dir}',
#                                                            'file_path': '${paths.responses_path}'}},
#                      'cell_types_list': '${quality_checks.cell_types_list}',
#                      'chirp_qi': '${quality_checks.chirp_qi}',
#                      'classifier_confidence': '${quality_checks.classifier_confidence}',
#                      'd_qi': '${quality_checks.d_qi}',
#                      'filter_cell_types': '${quality_checks.filter_cell_types}',
#                      'filter_counts': '${quality_checks.filter_counts}',
#                      'qi_logic': '${quality_checks.qi_logic}',
#                      'verbose': '${quality_checks.verbose}'},
#     'response_type': 'natural'}

# %% [markdown]
# While this may look complex, it effectively amounts to resolving a few intermediate steps in loading the data, and should be read from the inside out.
#
# When written more simply, it is equivalent to the following:

# %%
#responses_path = get_local_file_path(file_path=cfg.paths.responses_path, cache_folder=cfg.paths.data_dir)
responses_path = "/home/bethge/bkr618/openretina_cache/data/euler_lab/hoefling_2024/responses/rgc_natstim_2024-08-14.h5"
responses_dict = load_h5_into_dict(file_path=responses_path)

filtered_responses_dict = filter_responses(responses_dict, **cfg.quality_checks)

final_responses = make_final_responses(filtered_responses_dict, response_type="natural")
# Out:
# Loading HDF5 file contents:   0%|          | 0/2077 [00:00<?, ?item/s]
# Original dataset contains 7863 neurons over 67 fields
#  ------------------------------------
# Dropped 0 fields that did not contain the target cell types (67 remaining)
# Overall, dropped 3034 neurons of non-target cell types (-38.59%).
#  ------------------------------------
# Dropped 0 fields with quality indices below threshold (67 remaining)
# Overall, dropped 980 neurons over quality checks (-20.29%).
#  ------------------------------------
# Dropped 0 fields with classifier confidences below 0.25
# Overall, dropped 705 neurons with classifier confidences below 0.25 (-18.32%).
#  ------------------------------------
#  ------------------------------------
# Final dataset contains 3144 neurons over 67 fields
# Total number of cells dropped: 4719 (-60.02%)
# Upsampling natural spikes traces to get final responses.:   0%|          | 0/67 [00:00<?, ?it/s]

# %% [markdown]
# And here is how the final responses will be organised:

# %%
pp.pprint(final_responses)
# Out:
# {   'session_1_ventral1_20200226': ResponsesTrainTestSplit(train=numpy.ndarray(shape=(80, 16200)),
#                                                            test_dict={   'test': numpy.ndarray(shape=(80, 750))},
#                                                            test_by_trial=numpy.ndarray(shape=(80, 750, 3)),
#                                                            stim_id='natural',
#                                                            session_kwargs={   'eye': 'left',
#                                                                               'group_assignment': numpy.ndarray(shape=(80,)),
#                                                                               'roi_ids': numpy.ndarray(shape=(80,)),
#                                                                               'roi_mask': numpy.ndarray(shape=(64, 64)),
#                                                                               'scan_sequence_idx': np.int64(18)}),
#     'session_1_ventral1_20200528': ResponsesTrainTestSplit(train=numpy.ndarray(shape=(42, 16200)),
#                                                            test_dict={   'test': numpy.ndarray(shape=(42, 750))},
#                                                            test_by_trial=numpy.ndarray(shape=(42, 750, 3)),
#                                                            stim_id='natural',
#                                                            session_kwargs={   'eye': 'left',
#                                                                               'group_assignment': numpy.ndarray(shape=(42,)),
#                                                                               'roi_ids': numpy.ndarray(shape=(42,)),
#                                                                               'roi_mask': numpy.ndarray(shape=(64, 64)),
#                                                                               'scan_sequence_idx': np.int64(4)}),
#     'session_1_ventral1_20200707': ResponsesTrainTestSplit(train=numpy.ndarray(shape=(74, 16200)),
#                                                            test_dict={   'test': numpy.ndarray(shape=(74, 750))},
#                                                            test_by_trial=numpy.ndarray(shape=(74, 750, 3)),
#                                                            stim_id='natural',
#                                                            session_kwargs={   'eye': 'left',
#                                                                               'group_assignment':
#  ... Exceeded maximum number of lines ...

# %% [markdown]
# # Creating dataloaders

# %% [markdown]
# The corresponding code in `train.py` is:
# ```
# dataloaders = hydra.utils.instantiate(
#         cfg.dataloader,
#         neuron_data_dictionary=neuron_data_dict,
#         movies_dictionary=movies_dict,
#     )
# ```

# %%
pp.pprint(cfg.dataloader)
# Out:
# {   '_convert_': 'object',
#     '_target_': 'openretina.data_io.hoefling_2024.dataloaders.natmov_dataloaders_v2',
#     'allow_over_boundaries': True,
#     'batch_size': 128,
#     'train_chunk_size': 50,
#     'validation_clip_indices': list(len=15)}

# %%
dataloaders = natmov_dataloaders_v2(
    neuron_data_dictionary=final_responses,
    movies_dictionary=movie_stimuli,
    allow_over_boundaries=True,
    batch_size=128,
    train_chunk_size=50,
    validation_clip_indices=cfg.dataloader.validation_clip_indices,
)
# Out:
# Creating movie dataloaders:   0%|          | 0/67 [00:00<?, ?it/s]

# %%
print(dataloaders.keys())
# Out:
# dict_keys(['train', 'validation', 'test'])

# %%
for key, loader in dataloaders['train'].items():
    batch = next(iter(loader))  # get first batch from this DataLoader
    print(key)
    print(batch.inputs.shape)   # if batch is a DataPoint
    print(batch.targets.shape)  # if available
# Out:
# session_1_ventral1_20200226
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 80])
# session_1_ventral1_20200528
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 42])
# session_1_ventral1_20200707
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 74])
# session_1_ventral1_20201021
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 32])
# session_1_ventral1_20201030
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 40])
# session_1_ventral1_20210929
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 48])
# session_1_ventral1_20210930
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 26])
# session_1_ventral2_20200302
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 41])
# session_1_ventral2_20200707
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 56])
# session_1_ventral2_20201021
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 39])
# session_1_ventral2_20201022
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 42])
# session_1_ventral2_20201030
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 84])
# session_1_ventral2_20201117
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 46])
# session_1_ventral2_20210910
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 44])
# session_1_ventral2_20210921
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 33])
# session_1_ventral2_20210929
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 59])
# session_1_ventral2_20210930
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 56])
# session_1_ventral2_20211130
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 35])
# session_2_ventral1_20200226
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 72])
# session_2_ventral1_20200303
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 50])
# session_2_ventral1_20200528
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 42])
# session_2_ventral1_20200529
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 29])
# session_2_ventral1_20200701
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 55])
# session_2_ventral1_20201021
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 49])
# session_2_ventral1_20201030
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 55])
# session_2_ventral1_20210929
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 44])
# session_2_ventral2_20200303
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 44])
# session_2_ventral2_20201016
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 59])
# session_2_ventral2_20201021
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 47])
# session_2_ventral2_20201022
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 48])
# session_2_ventral2_20201030
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 91])
# session_2_ventral2_20201117
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 55])
# session_2_ventral2_20210910
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 52])
# session_2_ventral2_20210921
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 38])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 2
#       1 for key, loader in dataloaders['train'].items():
# ----> 2     batch = next(iter(loader))  # get first batch from this DataLoader
#       3     print(key)
#       4     print(batch.inputs.shape)   # if batch is a DataPoint
#
# File ~/.local/lib/python3.13/site-packages/torch/utils/data/dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File ~/.local/lib/python3.13/site-packages/torch/utils/data/dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/.local/lib/python3.13/site-packages/torch/utils/data/_utils/fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File ~/.local/lib/python3.13/site-packages/torch/utils/data/_utils/collate.py:398, in default_collate(batch)
#     337 def default_collate(batch):
#     338     r"""
#     339     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     340
#    (...)    396         >>> default_collate(batch)  # Handle `CustomType` automatically
#     397     """
# --> 398     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~/.local/lib/python3.13/site-packages/torch/utils/data/_utils/collate.py:196, in collate(batch, collate_fn_map)
#     191         return {
#     192             key: collate([d[key] for d in batch], collate_fn_map=collate_fn_map)
#     193             for key in elem
#     194         }
#     195 elif isinstance(elem, tuple) and hasattr(elem, "_fields"):  # namedtuple
# --> 196     return elem_type(
#     197         *(
#     198             collate(samples, collate_fn_map=collate_fn_map)
#     199             for samples in zip(*batch)
#     200         )
#     201     )
#     202 elif isinstance(elem, collections.abc.Sequence):
#     203     # check to make sure that the elements in batch have consistent size
#     204     it = iter(batch)
#
# File ~/.local/lib/python3.13/site-packages/torch/utils/data/_utils/collate.py:198, in <genexpr>(.0)
#     191         return {
#     192             key: collate([d[key] for d in batch], collate_fn_map=collate_fn_map)
#     193             for key in elem
#     194         }
#     195 elif isinstance(elem, tuple) and hasattr(elem, "_fields"):  # namedtuple
#     196     return elem_type(
#     197         *(
# --> 198             collate(samples, collate_fn_map=collate_fn_map)
#     199             for samples in zip(*batch)
#     200         )
#     201     )
#     202 elif isinstance(elem, collections.abc.Sequence):
#     203     # check to make sure that the elements in batch have consistent size
#     204     it = iter(batch)
#
# File ~/.local/lib/python3.13/site-packages/torch/utils/data/_utils/collate.py:155, in collate(batch, collate_fn_map)
#     153 if collate_fn_map is not None:
#     154     if elem_type in collate_fn_map:
# --> 155         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     157     for collate_type in collate_fn_map:
#     158         if isinstance(elem, collate_type):
#
# File ~/.local/lib/python3.13/site-packages/torch/utils/data/_utils/collate.py:272, in collate_tensor_fn(batch, collate_fn_map)
#     270     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     271     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 272 return torch.stack(batch, 0, out=out)
#
# KeyboardInterrupt:

# %%
len(dataloaders["train"]['session_1_ventral1_20200226'])
# Out:
# 2

# %%
for i, batch in enumerate(dataloaders["train"]["session_1_ventral1_20200226"]):
    print(f"n_sessions: {len(dataloaders['train'])}")
    
    print(batch.inputs.shape)
    print(batch.targets.shape)
# Out:
# n_sessions: 67
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 80])
# n_sessions: 67
# torch.Size([128, 2, 50, 72, 64])
# torch.Size([128, 50, 80])

# %%
for batch in dataloaders["test"]["session_2_ventral2_20201022"]:
    print(f"n_sessions: {len(dataloaders['train'])}")
    print(batch.inputs.shape)
    print(batch.targets.shape)
# Out:
# n_sessions: 67
# torch.Size([1, 2, 750, 72, 64])
# torch.Size([1, 750, 48])

# %%
for batch in dataloaders["validation"]["session_1_ventral1_20200226"]:
    print(f"n_sessions: {len(dataloaders['train'])}")
    print(batch.inputs.shape)
    print(batch.targets.shape)
    break
# Out:
# n_sessions: 67
# torch.Size([15, 2, 150, 72, 64])
# torch.Size([15, 150, 80])

# %%
pp.pprint(dataloaders['train'])
# Out:
# {   'session_1_ventral1_20200226': torch.utils.data.DataLoader(Dataset: MovieDataSet with 80 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral1_20200528': torch.utils.data.DataLoader(Dataset: MovieDataSet with 42 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral1_20200707': torch.utils.data.DataLoader(Dataset: MovieDataSet with 74 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral1_20201021': torch.utils.data.DataLoader(Dataset: MovieDataSet with 32 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral1_20201030': torch.utils.data.DataLoader(Dataset: MovieDataSet with 40 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral1_20210929': torch.utils.data.DataLoader(Dataset: MovieDataSet with 48 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral1_20210930': torch.utils.data.DataLoader(Dataset: MovieDataSet with 26 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral2_20200302': torch.utils.data.DataLoader(Dataset: MovieDataSet with 41 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral2_20200707': torch.utils.data.DataLoader(Dataset: MovieDataSet with 56 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral2_20201021': torch.utils.data.DataLoader(Dataset: MovieDataSet with 39 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral2_20201022': torch.utils.data.DataLoader(Dataset: MovieDataSet with 42 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral2_20201030': torch.utils.data.DataLoader(Dataset: MovieDataSet with 84 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral2_20201117': torch.utils.data.DataLoader(Dataset: MovieDataSet with 46 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral2_20210910': torch.utils.data.DataLoader(Dataset: MovieDataSet with 44 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral2_20210921': torch.utils.data.DataLoader(Dataset: MovieDataSet with 33 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral2_20210929': torch.utils.data.DataLoader(Dataset: MovieDataSet with 59 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral2_20210930': torch.utils.data.DataLoader(Dataset: MovieDataSet with 56 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_1_ventral2_20211130': torch.utils.data.DataLoader(Dataset: MovieDataSet with 35 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral1_20200226': torch.utils.data.DataLoader(Dataset: MovieDataSet with 72 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral1_20200303': torch.utils.data.DataLoader(Dataset: MovieDataSet with 50 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral1_20200528': torch.utils.data.DataLoader(Dataset: MovieDataSet with 42 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral1_20200529': torch.utils.data.DataLoader(Dataset: MovieDataSet with 29 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral1_20200701': torch.utils.data.DataLoader(Dataset: MovieDataSet with 55 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral1_20201021': torch.utils.data.DataLoader(Dataset: MovieDataSet with 49 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral1_20201030': torch.utils.data.DataLoader(Dataset: MovieDataSet with 55 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral1_20210929': torch.utils.data.DataLoader(Dataset: MovieDataSet with 44 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral2_20200303': torch.utils.data.DataLoader(Dataset: MovieDataSet with 44 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral2_20201016': torch.utils.data.DataLoader(Dataset: MovieDataSet with 59 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral2_20201021': torch.utils.data.DataLoader(Dataset: MovieDataSet with 47 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral2_20201022': torch.utils.data.DataLoader(Dataset: MovieDataSet with 48 neuron responses to a movie of shape [2, 13950, 72, 64].),
#     'session_2_ventral2_20201030':
#  ... Exceeded maximum number of lines ...

# %%
print(f"n sessions train: {len(dataloaders['train'].keys())}")
print(dataloaders["train"]["session_1_ventral1_20200226"])
print(dataloaders['validation'].shape)
print(dataloaders['test'].shape)
# Out:
# n:sessions: 67
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 print(f"n:sessions: {len(dataloaders['train'].keys())}")
# ----> 2 print(dataloaders['validation'].shape)
#       3 print(dataloaders['test'].shape)
#
# AttributeError: 'dict' object has no attribute 'shape'

# %%
pp.pprint(dataloaders)
# Out:
# {   'test': {   'session_1_ventral1_20200226': torch.utils.data.DataLoader(Dataset: MovieDataSet with 80 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral1_20200528': torch.utils.data.DataLoader(Dataset: MovieDataSet with 42 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral1_20200707': torch.utils.data.DataLoader(Dataset: MovieDataSet with 74 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral1_20201021': torch.utils.data.DataLoader(Dataset: MovieDataSet with 32 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral1_20201030': torch.utils.data.DataLoader(Dataset: MovieDataSet with 40 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral1_20210929': torch.utils.data.DataLoader(Dataset: MovieDataSet with 48 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral1_20210930': torch.utils.data.DataLoader(Dataset: MovieDataSet with 26 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral2_20200302': torch.utils.data.DataLoader(Dataset: MovieDataSet with 41 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral2_20200707': torch.utils.data.DataLoader(Dataset: MovieDataSet with 56 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral2_20201021': torch.utils.data.DataLoader(Dataset: MovieDataSet with 39 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral2_20201022': torch.utils.data.DataLoader(Dataset: MovieDataSet with 42 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral2_20201030': torch.utils.data.DataLoader(Dataset: MovieDataSet with 84 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral2_20201117': torch.utils.data.DataLoader(Dataset: MovieDataSet with 46 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral2_20210910': torch.utils.data.DataLoader(Dataset: MovieDataSet with 44 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral2_20210921': torch.utils.data.DataLoader(Dataset: MovieDataSet with 33 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral2_20210929': torch.utils.data.DataLoader(Dataset: MovieDataSet with 59 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral2_20210930': torch.utils.data.DataLoader(Dataset: MovieDataSet with 56 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_1_ventral2_20211130': torch.utils.data.DataLoader(Dataset: MovieDataSet with 35 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral1_20200226': torch.utils.data.DataLoader(Dataset: MovieDataSet with 72 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral1_20200303': torch.utils.data.DataLoader(Dataset: MovieDataSet with 50 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral1_20200528': torch.utils.data.DataLoader(Dataset: MovieDataSet with 42 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral1_20200529': torch.utils.data.DataLoader(Dataset: MovieDataSet with 29 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral1_20200701': torch.utils.data.DataLoader(Dataset: MovieDataSet with 55 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral1_20201021': torch.utils.data.DataLoader(Dataset: MovieDataSet with 49 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral1_20201030': torch.utils.data.DataLoader(Dataset: MovieDataSet with 55 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral1_20210929': torch.utils.data.DataLoader(Dataset: MovieDataSet with 44 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral2_20200303': torch.utils.data.DataLoader(Dataset: MovieDataSet with 44 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral2_20201016': torch.utils.data.DataLoader(Dataset: MovieDataSet with 59 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral2_20201021': torch.utils.data.DataLoader(Dataset: MovieDataSet with 47 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral2_20201022': torch.utils.data.DataLoader(Dataset: MovieDataSet with 48 neuron responses to a movie of shape [2, 750, 72, 64].),
#                 'session_2_ventral2_20201030':
#  ... Exceeded maximum number of lines ...

# %% [markdown]
# Let's also compute `data_info`, which is used to initialise certain model components and to save important metadata about stimuli and responses within the model.

# %%
data_info = compute_data_info(neuron_data_dictionary=final_responses, movies_dictionary=movie_stimuli)

pp.pprint(data_info)
# Out:
# {   'input_shape': (2, 72, 64),
#     'movie_norm_dict': {   'default': {   'norm_mean': 36.979288270899204,
#                                           'norm_std': 36.98463253226166}},
#     'n_neurons_dict': {   'session_1_ventral1_20200226': 80,
#                           'session_1_ventral1_20200528': 42,
#                           'session_1_ventral1_20200707': 74,
#                           'session_1_ventral1_20201021': 32,
#                           'session_1_ventral1_20201030': 40,
#                           'session_1_ventral1_20210929': 48,
#                           'session_1_ventral1_20210930': 26,
#                           'session_1_ventral2_20200302': 41,
#                           'session_1_ventral2_20200707': 56,
#                           'session_1_ventral2_20201021': 39,
#                           'session_1_ventral2_20201022': 42,
#                           'session_1_ventral2_20201030': 84,
#                           'session_1_ventral2_20201117': 46,
#                           'session_1_ventral2_20210910': 44,
#                           'session_1_ventral2_20210921': 33,
#                           'session_1_ventral2_20210929': 59,
#                           'session_1_ventral2_20210930': 56,
#                           'session_1_ventral2_20211130': 35,
#                           'session_2_ventral1_20200226': 72,
#                           'session_2_ventral1_20200303': 50,
#                           'session_2_ventral1_20200528': 42,
#                           'session_2_ventral1_20200529': 29,
#                           'session_2_ventral1_20200701': 55,
#                           'session_2_ventral1_20201021': 49,
#                           'session_2_ventral1_20201030': 55,
#                           'session_2_ventral1_20210929':
#  ... Exceeded maximum number of lines ...

# %% [markdown]
# # Tentatives Transf

# %%
from openretina.models.transformer_core import ViViTCore

# %% [markdown]
# # Model initialisation

# %% [markdown]
# Relevant `train.py` section:
# ```
# cfg.model.n_neurons_dict = data_info["n_neurons_dict"]
#
# model = hydra.utils.instantiate(cfg.model, data_info=data_info)
# ```

# %% [markdown]
# The config for the model will contain all the relevant hyperparameters for it:

# %%
pp.pprint(cfg.model)
# Out:
# {   'core': {   '_convert_': 'object',
#                 '_target_': 'openretina.modules.core.base_core.SimpleCoreWrapper',
#                 'channels': '???',
#                 'color_squashing_weights': None,
#                 'convolution_type': 'custom_separable',
#                 'cut_first_n_frames': 0,
#                 'downsample_input_kernel_size': None,
#                 'dropout_rate': 0.0,
#                 'gamma_hidden': 0.0,
#                 'gamma_in_sparse': 0.0,
#                 'gamma_input': 0.0,
#                 'gamma_temporal': 40.0,
#                 'hidden_padding': [0, 2, 2],
#                 'input_padding': 0,
#                 'maxpool_every_n_layers': None,
#                 'spatial_kernel_sizes': [11, 5],
#                 'temporal_kernel_sizes': [21, 11]},
#     'hidden_channels': [16, 16],
#     'in_shape': [2, 150, 18, 16],
#     'learning_rate': 0.01,
#     'n_neurons_dict': '???',
#     'readout': {   '_convert_': 'object',
#                    '_target_': 'openretina.modules.readout.multi_readout.MultiGaussianReadoutWrapper',
#                    'bias': True,
#                    'gamma_masks': 0.0,
#                    'gamma_readout': 0.4,
#                    'gaussian_masks': True,
#                    'gaussian_mean_scale': 6.0,
#                    'gaussian_var_scale': 4.0,
#                    'in_shape':
#  ... Exceeded maximum number of lines ...

# %% [markdown]
# As you can see, the value for `n_neurons_dict` is missing, and needs to be set from data_info.

# %%
n_neurons_dict = data_info["n_neurons_dict"]
from openretina.models.core_readout import TransformerCoreReadout

model = TransformerCoreReadout(
    in_shape=(128,2, 50, 72, 64),  # (batch, channels, time, height, width)
    n_neurons_dict=n_neurons_dict,
    emb_dim=32,
    in_channels=2,
    img_size=(72,64),
    patch_size=(8, 8),
    temporal_patch_size=5,
    num_spatial_blocks=4,
    num_temporal_blocks=4,
    num_heads=2,
    mlp_ratio=4.0,
    dropout=0.1,  
    chunk_size=64,
    pad_frame=True,
    temporal_stride=1,
    spatial_stride=1,
    ptoken=0.1,
    readout_bias=True,
    readout_init_mu_range=0.5,  
    readout_init_sigma_range=4.0, 
    readout_gamma=0.4,
    readout_reg_avg=False,
    learning_rate=0.01,
    data_info=data_info,
)
# Out:
# 2025-10-31 16:09:32,711 - INFO - in_shape_readout=(32, 11, 10, 9)
# 1. Starting init
# 2. Basic attributes set
# 3. Padding computed: t=4, h=7, w=7
# 4. Padding layer created
# 5. Tokenizer created
# 6. Transformer created
# 7. Patch dimensions computed
# 8. About to initialize weights
# ✓ Weights initialized
# 9. Weights initialized - INIT COMPLETE

# %%
from pytorch_lightning.utilities.model_summary import summarize


summary = summarize(model, max_depth=-1)  # full depth
print(summary)
# Out:
#     | Name                                                         | Type                               | Params | Mode
# ------------------------------------------------------------------------------------------------------------------------------
# 0   | core                                                         | TransformerCoreWrapper             | 442 K  | train
# 1   | core.pad                                                     | ZeroPad3d                          | 0      | train
# 2   | core.tokenizer                                               | VideoTokenizer                     | 42.3 K | train
# 3   | core.tokenizer.ln                                            | LayerNorm                          | 1.3 K  | train
# 4   | core.tokenizer.fc                                            | Linear                             | 41.0 K | train
# 5   | core.transformer                                             | SpatioTemporalTransformer          | 400 K  | train
# 6   | core.transformer.spatial_transformer                         | SpatialTransformer                 | 200 K  | train
# 7   | core.transformer.spatial_transformer.blocks                  | ModuleList                         | 199 K  | train
# 8   | core.transformer.spatial_transformer.blocks.0                | AttentionBlock                     | 50.0 K | train
# 9   | core.transformer.spatial_transformer.blocks.0.ln1            | LayerNorm                          | 128    | train
# 10  | core.transformer.spatial_transformer.blocks.0.attn           | MultiheadAttention                 | 16.6 K | train
# 11  | core.transformer.spatial_transformer.blocks.0.attn.out_proj  | NonDynamicallyQuantizableLinear    | 4.2 K  | train
# 12  | core.transformer.spatial_transformer.blocks.0.ln2            | LayerNorm                          | 128    | train
# 13  | core.transformer.spatial_transformer.blocks.0.mlp            | Sequential                         | 33.1 K | train
# 14  | core.transformer.spatial_transformer.blocks.0.mlp.0          | Linear                             | 16.6 K | train
# 15  | core.transformer.spatial_transformer.blocks.0.mlp.1          | GELU                               | 0      | train
# 16  | core.transformer.spatial_transformer.blocks.0.mlp.2          | Dropout                            | 0      | train
# 17  | core.transformer.spatial_transformer.blocks.0.mlp.3          | Linear                             | 16.4 K | train
# 18  | core.transformer.spatial_transformer.blocks.0.mlp.4          | Dropout                            | 0      | train
# 19  | core.transformer.spatial_transformer.blocks.1                | AttentionBlock                     | 50.0 K | train
# 20  | core.transformer.spatial_transformer.blocks.1.ln1            | LayerNorm                          | 128    | train
# 21  | core.transformer.spatial_transformer.blocks.1.attn           | MultiheadAttention                 | 16.6 K | train
# 22  | core.transformer.spatial_transformer.blocks.1.attn.out_proj  | NonDynamicallyQuantizableLinear    | 4.2 K  | train
# 23  | core.transformer.spatial_transformer.blocks.1.ln2            | LayerNorm                          | 128    | train
# 24  | core.transformer.spatial_transformer.blocks.1.mlp            | Sequential                         | 33.1 K | train
# 25  | core.transformer.spatial_transformer.blocks.1.mlp.0          | Linear                             | 16.6 K | train
# 26  | core.transformer.spatial_transformer.blocks.1.mlp.1          | GELU                               | 0      | train
# 27  | core.transformer.spatial_transformer.blocks.1.mlp.2          | Dropout                            | 0      | train
# 28  | core.transformer.spatial_transformer.blocks.1.mlp.3          | Linear                             | 16.4 K | train
# 29  | core.transformer.spatial_transformer.blocks.1.mlp.4          | Dropout                            | 0      | train
# 30  | core.transformer.spatial_transformer.blocks.2                | AttentionBlock                     | 50.0 K | train
# 31  | core.transformer.spatial_transformer.blocks.2.ln1            | LayerNorm                          | 128    | train
# 32  | core.transformer.spatial_transformer.blocks.2.attn           | MultiheadAttention                 | 16.6 K | train
# 33  | core.transformer.spatial_transformer.blocks.2.attn.out_proj  | NonDynamicallyQuantizableLinear    | 4.2 K  | train
# 34  | core.transformer.spatial_transformer.blocks.2.ln2            | LayerNorm                          | 128    | train
# 35  | core.transformer.spatial_transformer.blocks.2.mlp            | Sequential                         | 33.1 K | train
# 36  | core.transformer.spatial_transformer.blocks.2.mlp.0          | Linear                             | 16.6 K | train
# 37  | core.transformer.spatial_transformer.blocks.2.mlp.1          | GELU                               | 0      | train
# 38  | core.transformer.spatial_transformer.blocks.2.mlp.2          | Dropout                            | 0      | train
# 39  | core.transformer.spatial_transformer.blocks.2.mlp.3          | Linear                             | 16.4 K | train
# 40  | core.transformer.spatial_transformer.blocks.2.mlp.4          | Dropout                            | 0      | train
# 41  | core.transformer.spatial_transformer.blocks.3                | AttentionBlock                     | 50.0 K | train
# 42  | core.transformer.spatial_transformer.blocks.3.ln1            | LayerNorm                          | 128    | train
# 43  | core.transformer.spatial_transformer.blocks.3.attn           | MultiheadAttention                 | 16.6 K | train
# 44  | core.transformer.spatial_transformer.blocks.3.attn.out_proj  | NonDynamicallyQuantizableLinear    | 4.2 K  | train
# 45  | core.transformer.spatial_transformer.blocks.3.ln2            | LayerNorm                          | 128    | train
# 46  | core.transformer.spatial_transformer.blocks.3.mlp            | Sequential                         | 33.1 K | train
# 47  | core.transformer.spatial_transformer.blocks.3.mlp.0          | Linear                             | 16.6 K | train
# 48  | core.transformer.spatial_transformer.blocks.3.mlp.1          | GELU                               | 0      | train
# 49  | core.transformer.spatial_transformer.blocks.3.mlp.2          | Dropout                            | 0      | train
# 50  | core.transformer.spatial_transformer.blocks.3.mlp.3          | Linear                             | 16.4 K | train
# 51  | core.transformer.spatial_transformer.blocks.3.mlp.4          | Dropout                            | 0      | train
# 52  | core.transformer.spatial_transformer.ln_final                | LayerNorm                          | 128    | train
# 53  | core.transformer.temporal_transformer                        | TemporalTransformer                | 200 K  | train
# 54  | core.transformer.temporal_transformer.blocks                 | ModuleList                         | 199 K  | train
# 55  | core.transformer.temporal_transformer.blocks.0               | AttentionBlock                     | 50.0 K | train
# 56  | core.transformer.temporal_transformer.blocks.0.ln1           | LayerNorm                          | 128    | train
# 57  | core.transformer.temporal_transformer.blocks.0.attn          | MultiheadAttention                 | 16.6 K | train
# 58  | core.transformer.temporal_transformer.blocks.0.attn.out_proj | NonDynamicallyQuantizableLinear    | 4.2 K  | train
# 59  | core.transformer.temporal_transformer.blocks.0.ln2           | LayerNorm                          | 128    | train
# 60  | core.transformer.temporal_transformer.blocks.0.mlp           | Sequential                         | 33.1 K | train
# 61  | core.transformer.temporal_transformer.blocks.0.mlp.0         | Linear                             | 16.6 K | train
# 62  | core.transformer.temporal_transformer.blocks.0.mlp.1         | GELU                               | 0      | train
# 63  | core.transformer.temporal_transformer.blocks.0.mlp.2         | Dropout                            | 0      | train
# 64  | core.transformer.temporal_transformer.blocks.0.mlp.3         | Linear                             | 16.4 K | train
# 65  | core.transformer.temporal_transformer.blocks.0.mlp.4         | Dropout                            | 0      | train
# 66  | core.transformer.temporal_transformer.blocks.1               | AttentionBlock                     | 50.0 K | train
# 67  | core.transformer.temporal_transformer.blocks.1.ln1           | LayerNorm                          | 128    | train
# 68  | core.transformer.temporal_transformer.blocks.1.attn          | MultiheadAttention                 | 16.6 K | train
# 69  | core.transformer.temporal_transformer.blocks.1.attn.out_proj | NonDynamicallyQuantizableLinear    | 4.2 K  | train
# 70  | core.transformer.temporal_transformer.blocks.1.ln2           | LayerNorm                          | 128    | train
# 71  | core.transformer.temporal_transformer.blocks.1.mlp           | Sequential                         | 33.1 K | train
# 72  | core.transformer.temporal_transformer.blocks.1.mlp.0         | Linear                             | 16.6 K | train
# 73  | core.transformer.temporal_transformer.blocks.1.mlp.1         | GELU                               | 0      | train
# 74  | core.transformer.temporal_transformer.blocks.1.mlp.2         | Dropout                            | 0      | train
# 75  | core.transformer.temporal_transformer.blocks.1.mlp.3         | Linear                             | 16.4 K | train
# 76  | core.transformer.temporal_transformer.blocks.1.mlp.4         | Dropout                            | 0      | train
# 77  | core.transformer.temporal_transformer.blocks.2               | AttentionBlock                     | 50.0 K | train
# 78  | core.transformer.temporal_transformer.blocks.2.ln1           | LayerNorm                          | 128    | train
# 79  | core.transformer.temporal_transformer.blocks.2.attn          | MultiheadAttention                 | 16.6 K | train
# 80  | core.transformer.temporal_transformer.blocks.2.attn.out_proj | NonDynamicallyQuantizableLinear    | 4.2 K  | train
# 81  | core.transformer.temporal_transformer.blocks.2.ln2           | LayerNorm                          | 128    | train
# 82  | core.transformer.temporal_transformer.blocks.2.mlp           | Sequential                         | 33.1 K | train
# 83  | core.transformer.temporal_transformer.blocks.2.mlp.0         | Linear                             | 16.6 K | train
# 84  | core.transformer.temporal_transformer.blocks.2.mlp.1         | GELU                               | 0      | train
# 85  | core.transformer.temporal_transformer.blocks.2.mlp.2         | Dropout                            | 0      | train
# 86  | core.transformer.temporal_transformer.blocks.2.mlp.3         | Linear                             | 16.4 K | train
# 87  | core.transformer.temporal_transformer.blocks.2.mlp.4         | Dropout                            | 0      | train
# 88  | core.transformer.temporal_transformer.blocks.3               | AttentionBlock                     | 50.0 K | train
# 89  | core.transformer.temporal_transformer.blocks.3.ln1           | LayerNorm                          | 128    | train
# 90  | core.transformer.temporal_transformer.blocks.3.attn          | MultiheadAttention                 | 16.6 K | train
# 91  | core.transformer.temporal_transformer.blocks.3.attn.out_proj | NonDynamicallyQuantizableLinear    | 4.2 K  | train
# 92  | core.transformer.temporal_transformer.blocks.3.ln2           | LayerNorm                          | 128    | train
# 93  | core.transformer.temporal_transformer.blocks.3.mlp           | Sequential                         | 33.1 K | train
# 94  | core.transformer.temporal_transformer.blocks.3.mlp.0         | Linear                             | 16.6 K | train
# 95  | core.transformer.temporal_transformer.blocks.3.mlp.1         | GELU                               | 0      | train
# 96  | core.transformer.temporal_transformer.blocks.3.mlp.2         | Dropout                            | 0      | train
# 97  | core.transformer.temporal_transformer.blocks.3.mlp.3         | Linear                             | 16.4 K | train
# 98  | core.transformer.temporal_transformer.blocks.3.mlp.4         | Dropout                            | 0      | train
# 99  | core.transformer.temporal_transformer.ln_final               | LayerNorm                          | 128    | train
# 100 | readout                                                      | MultiSampledGaussianReadoutWrapper | 223 K  | train
# 101 | readout.session_1_ventral1_20200226                          | FullGaussian2d                     | 5.7 K  | train
# 102 | readout.session_1_ventral1_20200528                          | FullGaussian2d                     | 3.0 K  | train
# 103 | readout.session_1_ventral1_20200707                          | FullGaussian2d                     | 5.3 K  | train
# 104 | readout.session_1_ventral1_20201021                          | FullGaussian2d                     | 2.3 K  | train
# 105 | readout.session_1_ventral1_20201030                          | FullGaussian2d                     | 2.8 K  | train
# 106 | readout.session_1_ventral1_20210929                          | FullGaussian2d                     | 3.4 K  | train
# 107 | readout.session_1_ventral1_20210930                          | FullGaussian2d                     | 1.8 K  | train
# 108 | readout.session_1_ventral2_20200302                          | FullGaussian2d                     | 2.9 K  | train
# 109 | readout.session_1_ventral2_20200707                          | FullGaussian2d                     | 4.0 K  | train
# 110 | readout.session_1_ventral2_20201021                          | FullGaussian2d                     | 2.8 K  | train
# 111 | readout.session_1_ventral2_20201022                          | FullGaussian2d                     | 3.0 K  | train
# 112 | readout.session_1_ventral2_20201030                          | FullGaussian2d                     | 6.0 K  | train
# 113 | readout.session_1_ventral2_20201117                          | FullGaussian2d                     | 3.3 K  | train
# 114 | readout.session_1_ventral2_20210910                          | FullGaussian2d                     | 3.1 K  | train
# 115 | readout.session_1_ventral2_20210921                          | FullGaussian2d                     | 2.3 K  | train
# 116 | readout.session_1_ventral2_20210929                          | FullGaussian2d                     | 4.2 K  | train
# 117 | readout.session_1_ventral2_20210930                          | FullGaussian2d                     | 4.0 K  | train
# 118 | readout.session_1_ventral2_20211130                          | FullGaussian2d                     | 2.5 K  | train
# 119 | readout.session_2_ventral1_20200226                          | FullGaussian2d                     | 5.1 K  | train
# 120 | readout.session_2_ventral1_20200303                          | FullGaussian2d                     | 3.6 K  | train
# 121 | readout.session_2_ventral1_20200528                          | FullGaussian2d                     | 3.0 K  | train
# 122 | readout.session_2_ventral1_20200529                          | FullGaussian2d                     | 2.1 K  | train
# 123 | readout.session_2_ventral1_20200701                          | FullGaussian2d                     | 3.9 K  | train
# 124 | readout.session_2_ventral1_20201021                          | FullGaussian2d                     | 3.5 K  | train
# 125 | readout.session_2_ventral1_20201030                          | FullGaussian2d                     | 3.9 K  | train
# 126 | readout.session_2_ventral1_20210929                          | FullGaussian2d                     | 3.1 K  | train
# 127 | readout.session_2_ventral2_20200303                          | FullGaussian2d                     | 3.1 K  | train
# 128 | readout.session_2_ventral2_20201016                          | FullGaussian2d                     | 4.2 K  | train
# 129 | readout.session_2_ventral2_20201021                          | FullGaussian2d                     | 3.3 K  | train
# 130 | readout.session_2_ventral2_20201022                          | FullGaussian2d                     | 3.4 K  | train
# 131 | readout.session_2_ventral2_20201030                          | FullGaussian2d                     | 6.5 K  | train
# 132 | readout.session_2_ventral2_20201117                          | FullGaussian2d                     | 3.9 K  | train
# 133 | readout.session_2_ventral2_20210910                          | FullGaussian2d                     | 3.7 K  | train
# 134 | readout.session_2_ventral2_20210921                          | FullGaussian2d                     | 2.7 K  | train
# 135 | readout.session_2_ventral2_20210929                          | FullGaussian2d                     | 3.4 K  | train
# 136 | readout.session_2_ventral2_20210930                          | FullGaussian2d                     | 3.2 K  | train
# 137 | readout.session_2_ventral2_20211130                          | FullGaussian2d                     | 2.2 K  | train
# 138 | readout.session_3_ventral1_20200226                          | FullGaussian2d                     | 5.3 K  | train
# 139 | readout.session_3_ventral1_20200303                          | FullGaussian2d                     | 3.6 K  | train
# 140 | readout.session_3_ventral1_20200529                          | FullGaussian2d                     | 3.1 K  | train
# 141 | readout.session_3_ventral1_20201021                          | FullGaussian2d                     | 2.6 K  | train
# 142 | readout.session_3_ventral1_20201030                          | FullGaussian2d                     | 3.4 K  | train
# 143 | readout.session_3_ventral2_20200302                          | FullGaussian2d                     | 3.1 K  | train
# 144 | readout.session_3_ventral2_20200701                          | FullGaussian2d                     | 3.3 K  | train
# 145 | readout.session_3_ventral2_20200707                          | FullGaussian2d                     | 5.5 K  | train
# 146 | readout.session_3_ventral2_20201022                          | FullGaussian2d                     | 3.6 K  | train
# 147 | readout.session_3_ventral2_20201117                          | FullGaussian2d                     | 3.1 K  | train
# 148 | readout.session_3_ventral2_20210910                          | FullGaussian2d                     | 2.6 K  | train
# 149 | readout.session_3_ventral2_20210921                          | FullGaussian2d                     | 3.6 K  | train
# 150 | readout.session_3_ventral2_20210929                          | FullGaussian2d                     | 2.2 K  | train
# 151 | readout.session_3_ventral2_20210930                          | FullGaussian2d                     | 2.7 K  | train
# 152 | readout.session_3_ventral2_20211130                          | FullGaussian2d                     | 2.6 K  | train
# 153 | readout.session_4_ventral1_20201021                          | FullGaussian2d                     | 2.9 K  | train
# 154 | readout.session_4_ventral1_20201030                          | FullGaussian2d                     | 355    | train
# 155 | readout.session_4_ventral2_20200303                          | FullGaussian2d                     | 2.8 K  | train
# 156 | readout.session_4_ventral2_20200707                          | FullGaussian2d                     | 4.3 K  | train
# 157 | readout.session_4_ventral2_20201022                          | FullGaussian2d                     | 3.8 K  | train
# 158 | readout.session_4_ventral2_20210910                          | FullGaussian2d                     | 2.1 K  | train
# 159 | readout.session_4_ventral2_20210921                          | FullGaussian2d                     | 2.4 K  | train
# 160 | readout.session_4_ventral2_20210929                          | FullGaussian2d                     | 2.9 K  | train
# 161 | readout.session_4_ventral2_20211130                          | FullGaussian2d                     | 2.3 K  | train
# 162 | readout.session_5_ventral1_20200226                          | FullGaussian2d                     | 5.0 K  | train
# 163 | readout.session_5_ventral2_20200303                          | FullGaussian2d                     | 4.2 K  | train
# 164 | readout.session_5_ventral2_20210910                          | FullGaussian2d                     | 2.1 K  | train
# 165 | readout.session_5_ventral2_20210921                          | FullGaussian2d                     | 1.8 K  | train
# 166 | readout.session_5_ventral2_20210929                          | FullGaussian2d                     | 3.1 K  | train
# 167 | readout.session_6_ventral2_20210921                          | FullGaussian2d                     | 2.9 K  | train
# 168 | loss                                                         | PoissonLoss3d                      | 0      | train
# 169 | correlation_loss                                             | CorrelationLoss3d                  | 0      | train
# ------------------------------------------------------------------------------------------------------------------------------
# 665 K     Trainable params
# 0         Non-trainable params
# 665 K     Total params
# 2.663     Total estimated model params size (MB)
# 170       Modules in train mode
# 0         Modules in eval mode

# %% [markdown]
# # Training

# %% [markdown]
# With data imported, models initialised and dataloaders set up, we can turn to training.
#
# ```
# log_folder = os.path.join(cfg.paths.output_dir, cfg.exp_name)
# os.makedirs(log_folder, exist_ok=True)
# logger_array = []
# for _, logger_params in cfg.logger.items():
#     logger = hydra.utils.instantiate(logger_params, save_dir=log_folder)
#     logger_array.append(logger)
#
# callbacks = [
#     hydra.utils.instantiate(callback_params) for callback_params in cfg.get("training_callbacks", {}).values()
# ]
#
# trainer = hydra.utils.instantiate(cfg.trainer, logger=logger_array, callbacks=callbacks)
# trainer.fit(model=model, train_dataloaders=train_loader, val_dataloaders=valid_loader)
# ```
#
# This section is a bit more involved in `train.py`, to leave flexibility for different loggers and callbacks configurations. We are going to keep it simple here.
#
# Let's first initialise a simple tensorboard logger:

# %%
log_save_path = os.path.join(cfg.paths.output_dir, "notebook_example")
os.makedirs(log_save_path, exist_ok=True)

logger = lightning.pytorch.loggers.TensorBoardLogger(
    name="tensorboard/",
    save_dir=log_save_path,
)

# %% [markdown]
# Then some training callbacks (i.e. utility functions that will be called during training):

# %%
early_stopping = lightning.pytorch.callbacks.EarlyStopping(
    monitor="val_correlation",
    patience=10,
    mode="max",
    verbose=False,
    min_delta=0.001,
)

lr_monitor = lightning.pytorch.callbacks.LearningRateMonitor(logging_interval="epoch")

model_checkpoint = lightning.pytorch.callbacks.ModelCheckpoint(
    monitor="val_correlation", mode="max", save_weights_only=False
)

# %% [markdown]
# We can then instantiate the trainer:

# %%
trainer = lightning.Trainer(max_epochs=100, logger=logger, callbacks=[early_stopping, lr_monitor, model_checkpoint])
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %% [markdown]
# Finally, we can start training. Before doing sp though, we can initialise the tensorboard jupyter integration, to visualize how training progresses.
#
# Run the following cell once or twice until the tensorboard extension UI shows up. Once is shows, note that at the beginning it will show no data (unless you have run this notebook before), because we have not started the trainer yet.
#
# When you run the cell containing `trainer.fit` you can then come back to the tensorboard extension, reload the window *within the extension* by clicking the refresh icon in the top right, and follow the training.

# %%
# %reload_ext tensorboard

# %tensorboard --logdir {log_save_path}
# Out:
# Reusing TensorBoard on port 6006 (pid 4040261), started 0:00:02 ago. (Use '!kill 4040261' to kill it.)
#       <iframe id="tensorboard-frame-25d5604c7c50ef20" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-25d5604c7c50ef20");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# The only last important step before calling the trainer is to convert the dictionary of dataloaders we have into a unified iterator that will cycle through all sessions during training and evaluation:

# %%
train_loader = LongCycler(dataloaders["train"])
val_loader = ShortCycler(dataloaders["validation"])

# %%
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
# Out:
# Total parameters: 246,168
# Trainable parameters: 246,168

# %%
import torch

# Check if CUDA is available
print(f"CUDA available: {torch.cuda.is_available()}")

# Number of GPUs
print(f"Number of GPUs: {torch.cuda.device_count()}")

# Current GPU
if torch.cuda.is_available():
    print(f"Current GPU: {torch.cuda.current_device()}")
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    
    # Detailed info for each GPU
    for i in range(torch.cuda.device_count()):
        print(f"\n=== GPU {i} ===")
        print(f"Name: {torch.cuda.get_device_name(i)}")
        props = torch.cuda.get_device_properties(i)
        print(f"Total Memory: {props.total_memory / 1e9:.2f} GB")
        print(f"Compute Capability: {props.major}.{props.minor}")
        
    # Current memory usage
    print(f"\n=== Current Memory Usage ===")
    print(f"Allocated: {torch.cuda.memory_allocated(0) / 1e9:.2f} GB")
    print(f"Cached: {torch.cuda.memory_reserved(0) / 1e9:.2f} GB")
    print(f"Free: {(props.total_memory - torch.cuda.memory_allocated(0)) / 1e9:.2f} GB")
# Out:
# CUDA available: True
# Number of GPUs: 1
# Current GPU: 0
# GPU Name: NVIDIA GeForce RTX 2080 Ti
#
# === GPU 0 ===
# Name: NVIDIA GeForce RTX 2080 Ti
# Total Memory: 11.55 GB
# Compute Capability: 7.5
#
# === Current Memory Usage ===
# Allocated: 0.00 GB
# Cached: 0.00 GB
# Free: 11.55 GB

# %%
def get_model_memory(model):
    """Calculate memory used by model parameters"""
    param_size = 0
    buffer_size = 0
    
    for param in model.parameters():
        param_size += param.nelement() * param.element_size()
    
    for buffer in model.buffers():
        buffer_size += buffer.nelement() * buffer.element_size()
    
    total_size = param_size + buffer_size
    
    print(f"Parameter memory: {param_size / 1e6:.2f} MB")
    print(f"Buffer memory: {buffer_size / 1e6:.2f} MB")
    print(f"Total model memory: {total_size / 1e6:.2f} MB")
    
    return total_size

# Usage
get_model_memory(model)
# Out:
# Parameter memory: 0.98 MB
# Buffer memory: 0.00 MB
# Total model memory: 0.98 MB
# 984672

# %%
def estimate_memory_for_batch_size(model, input_shape, batch_sizes):
    """Estimate GPU memory usage for models expecting (B,C,T,H,W)"""
    import gc
    model.eval()
    torch.cuda.empty_cache()

    for bs in batch_sizes:
        try:
            torch.cuda.reset_peak_memory_stats()

            # Replace batch dimension in input_shape
            shape = (bs, *input_shape[1:])
            dummy = torch.randn(*shape, device="cuda")

            with torch.no_grad():
                _ = model(dummy)

            peak = torch.cuda.max_memory_allocated() / 1e9
            print(f"Batch size {bs:3d}: {peak:.2f} GB")

        except RuntimeError:
            print(f"Batch size {bs:3d}: OOM (Out of Memory)")
            break

        finally:
            del dummy, _
            gc.collect()
            torch.cuda.empty_cache()

# %%
import torch
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# 3488

# %%
import torch
print(torch.cuda.get_device_name(0))
print(f"Allocated: {torch.cuda.memory_allocated()/1e9:.2f} GB")
print(f"Reserved: {torch.cuda.memory_reserved()/1e9:.2f} GB")
print(f"Total: {torch.cuda.get_device_properties(0).total_memory/1e9:.2f} GB")
# Out:
# NVIDIA GeForce RTX 2080 Ti
# Allocated: 0.01 GB
# Reserved: 1.19 GB
# Total: 11.55 GB

# %%
with torch.cuda.profiler.profile():
    with torch.no_grad():
        _ = model(torch.randn(1, 2, 50, 72, 64, device='cuda'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[30], line 3
#       1 with torch.cuda.profiler.profile():
#       2     with torch.no_grad():
# ----> 3         _ = model(torch.randn(1, 2, 50, 72, 64, device='cuda'))
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/open-retina/openretina/models/core_readout.py:68, in BaseCoreReadout.forward(self, x, data_key)
#      67 def forward(self, x: Float[torch.Tensor, "batch channels t h w"], data_key: str | None = None) -> torch.Tensor:
# ---> 68     output_core = self.core(x)
#      69     output_readout = self.readout(output_core, data_key=data_key)
#      70     return output_readout
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/open-retina/openretina/modules/core/transformer_core.py:141, in TransformerCoreWrapper.forward(self, input_)
#     139 # Tokenize input
#     140 pad_input = self.pad(input_)
# --> 141 embeddings, TP, SP = self.tokenizer(pad_input)
#     142 # embeddings shape: (B, TP, SP, Demb)
#     143
#     144 # Apply spatiotemporal transformer
#     145 output = self.transformer(embeddings, TP, SP)
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/open-retina/openretina/models/new_tokenizer.py:93, in VideoTokenizer.forward(self, x)
#      90 x = x.view(B, num_temporal_patches, num_spatial_patches, self.flatten_dim)
#      92 # Embed
# ---> 93 x = self.ln(x)
#      94 x = self.fc(x)
#      95 x = rearrange(x, "b t s d -> b (t s) d")
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/normalization.py:217, in LayerNorm.forward(self, input)
#     216 def forward(self, input: Tensor) -> Tensor:
# --> 217     return F.layer_norm(
#     218         input, self.normalized_shape, self.weight, self.bias, self.eps
#     219     )
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/functional.py:2910, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2900 if has_torch_function_variadic(input, weight, bias):
#    2901     return handle_torch_function(
#    2902         layer_norm,
#    2903         (input, weight, bias),
#    (...)   2908         eps=eps,
#    2909     )
# -> 2910 return torch.layer_norm(
#    2911     input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled
#    2912 )
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument weight in method wrapper_CUDA__native_layer_norm)

# %%
nvidia-smi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 nvidia-smi
#
# NameError: name 'nvidia' is not defined

# %%
import torch

# Clear cache first
torch.cuda.empty_cache()

# Check before
print("=== BEFORE MODEL ===")
print(f"Allocated: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
print(f"Reserved: {torch.cuda.memory_reserved() / 1e9:.2f} GB")

# Move model to GPU
model = model.to('cuda')

print("\n=== AFTER MODEL TO GPU ===")
print(f"Allocated: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
print(f"Reserved: {torch.cuda.memory_reserved() / 1e9:.2f} GB")

# Create dummy batch
dummy_input = torch.randn(128, 2, 50, 72, 64).to('cuda')

print("\n=== AFTER CREATING INPUT ===")
print(f"Allocated: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
print(f"Reserved: {torch.cuda.memory_reserved() / 1e9:.2f} GB")

# Forward pass
output = model(dummy_input)

print("\n=== AFTER FORWARD PASS ===")
print(f"Allocated: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
print(f"Reserved: {torch.cuda.memory_reserved() / 1e9:.2f} GB")

# Backward pass
loss = output.sum()
loss.backward()

print("\n=== AFTER BACKWARD PASS ===")
print(f"Allocated: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
print(f"Reserved: {torch.cuda.memory_reserved() / 1e9:.2f} GB")
# Out:
# === BEFORE MODEL ===
# Allocated: 0.00 GB
# Reserved: 0.00 GB
#
# === AFTER MODEL TO GPU ===
# Allocated: 0.00 GB
# Reserved: 0.00 GB
#
# === AFTER CREATING INPUT ===
# Allocated: 0.24 GB
# Reserved: 0.24 GB
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[9], line 26
#      23 print(f"Reserved: {torch.cuda.memory_reserved() / 1e9:.2f} GB")
#      25 # Forward pass
# ---> 26 output = model(dummy_input)
#      28 print("\n=== AFTER FORWARD PASS ===")
#      29 print(f"Allocated: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/open-retina/openretina/models/core_readout.py:68, in BaseCoreReadout.forward(self, x, data_key)
#      67 def forward(self, x: Float[torch.Tensor, "batch channels t h w"], data_key: str | None = None) -> torch.Tensor:
# ---> 68     output_core = self.core(x)
#      69     output_readout = self.readout(output_core, data_key=data_key)
#      70     return output_readout
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/open-retina/openretina/modules/core/transformer_core.py:141, in TransformerCoreWrapper.forward(self, input_)
#     139 # Tokenize input
#     140 pad_input = self.pad(input_)
# --> 141 embeddings, TP, SP = self.tokenizer(pad_input)
#     142 # embeddings shape: (B, TP, SP, Demb)
#     143
#     144 # Apply spatiotemporal transformer
#     145 output = self.transformer(embeddings, TP, SP)
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/open-retina/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/open-retina/openretina/models/new_tokenizer.py:75, in VideoTokenizer.forward(self, x)
#      72     clip = clip.unfold(4, self.patch_size[1], self.spatial_stride)  # dim=W
#      73     # clip shape: (B, C, tp, n_h, n_w, ph, pw)
# ---> 75     clip = clip.contiguous().view(
#      76         B, C, self.temporal_patch_size,
#      77         num_patches_h, num_patches_w,
#      78         self.patch_size[0], self.patch_size[1]
#      79     )
#      80     patches.append(clip)
#      82 # Stack along temporal patches
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1.41 GiB. GPU 0 has a total capacity of 10.75 GiB of which 225.62 MiB is free. Including non-PyTorch memory, this process has 10.53 GiB memory in use. Of the allocated memory 10.35 GiB is allocated by PyTorch, and 1004.00 KiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import torch, gc

del model  # or any large tensors
gc.collect()
torch.cuda.empty_cache()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
trainer.fit(model, train_loader, val_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name             | Type                               | Params | Mode
# --------------------------------------------------------------------------------
# 0 | core             | TransformerCoreWrapper             | 123 K  | train
# 1 | readout          | MultiSampledGaussianReadoutWrapper | 122 K  | train
# 2 | loss             | PoissonLoss3d                      | 0      | train
# 3 | correlation_loss | CorrelationLoss3d                  | 0      | train
# --------------------------------------------------------------------------------
# 246 K     Trainable params
# 0         Non-trainable params
# 246 K     Total params
# 0.985     Total estimated model params size (MB)
# 170       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 trainer.fit(model, train_loader, val_loader)
#
# File ~/.local/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:560, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     558 self.training = True
#     559 self.should_stop = False
# --> 560 call._call_and_handle_interrupt(
#     561     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     562 )
#
# File ~/.local/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py:49, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47     if trainer.strategy.launcher is not None:
#      48         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 49     return trainer_fn(*args, **kwargs)
#      51 except _TunerExitException:
#      52     _call_teardown_hook(trainer)
#
# File ~/.local/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:598, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     591     download_model_from_registry(ckpt_path, self)
#     592 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     593     self.state.fn,
#     594     ckpt_path,
#     595     model_provided=True,
#     596     model_connected=self.lightning_module is not None,
#     597 )
# --> 598 self._run(model, ckpt_path=ckpt_path)
#     600 assert self.state.stopped
#     601 self.training = False
#
# File ~/.local/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:1011, in Trainer._run(self, model, ckpt_path)
#    1006 self._signal_connector.register_signal_handlers()
#    1008 # ----------------------------
#    1009 # RUN THE TRAINER
#    1010 # ----------------------------
# -> 1011 results = self._run_stage()
#    1013 # ----------------------------
#    1014 # POST-Training CLEAN UP
#    1015 # ----------------------------
#    1016 log.debug(f"{self.__class__.__name__}: trainer tearing down")
#
# File ~/.local/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:1053, in Trainer._run_stage(self)
#    1051 if self.training:
#    1052     with isolate_rng():
# -> 1053         self._run_sanity_check()
#    1054     with torch.autograd.set_detect_anomaly(self._detect_anomaly):
#    1055         self.fit_loop.run()
#
# File ~/.local/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:1082, in Trainer._run_sanity_check(self)
#    1079 call._call_callback_hooks(self, "on_sanity_check_start")
#    1081 # run eval step
# -> 1082 val_loop.run()
#    1084 call._call_callback_hooks(self, "on_sanity_check_end")
#    1086 # reset logger connector
#
# File ~/.local/lib/python3.13/site-packages/lightning/pytorch/loops/utilities.py:179, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     177     context_manager = torch.no_grad
#     178 with context_manager():
# --> 179     return loop_run(self, *args, **kwargs)
#
# File ~/.local/lib/python3.13/site-packages/lightning/pytorch/loops/evaluation_loop.py:145, in _EvaluationLoop.run(self)
#     143     self.batch_progress.is_last_batch = data_fetcher.done
#     144     # run step hooks
# --> 145     self._evaluation_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#     146 except StopIteration:
#     147     # this needs to wrap the `*_step` call too (not just `next`) for `dataloader_iter` support
#     148     break
#
# File ~/.local/lib/python3.13/site-packages/lightning/pytorch/loops/evaluation_loop.py:437, in _EvaluationLoop._evaluation_step(self, batch, batch_idx, dataloader_idx, dataloader_iter)
#     431 hook_name = "test_step" if trainer.testing else "validation_step"
#     432 step_args = (
#     433     self._build_step_args_from_hook_kwargs(hook_kwargs, hook_name)
#     434     if not using_dataloader_iter
#     435     else (dataloader_iter,)
#     436 )
# --> 437 output = call._call_strategy_hook(trainer, hook_name, *step_args)
#     439 self.batch_progress.increment_processed()
#     441 if using_dataloader_iter:
#     442     # update the hook kwargs now that the step method might have consumed the iterator
#
# File ~/.local/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py:329, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     326     return None
#     328 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 329     output = fn(*args, **kwargs)
#     331 # restore current_fx when nested context
#     332 pl_module._current_fx_name = prev_fx_name
#
# File ~/.local/lib/python3.13/site-packages/lightning/pytorch/strategies/strategy.py:412, in Strategy.validation_step(self, *args, **kwargs)
#     410 if self.model != self.lightning_module:
#     411     return self._forward_redirection(self.model, self.lightning_module, "validation_step", *args, **kwargs)
# --> 412 return self.lightning_module.validation_step(*args, **kwargs)
#
# File ~/open-retina/openretina/models/core_readout.py:91, in BaseCoreReadout.validation_step(self, batch, batch_idx)
#      89 def validation_step(self, batch: tuple[str, DataPoint], batch_idx: int) -> torch.Tensor:
#      90     session_id, data_point = batch
# ---> 91     model_output = self.forward(data_point.inputs, session_id)
#      92     loss = self.loss.forward(model_output, data_point.targets) / sum(model_output.shape)
#      93     regularization_loss_core = self.core.regularizer()
#
# File ~/open-retina/openretina/models/core_readout.py:68, in BaseCoreReadout.forward(self, x, data_key)
#      67 def forward(self, x: Float[torch.Tensor, "batch channels t h w"], data_key: str | None = None) -> torch.Tensor:
# ---> 68     output_core = self.core(x)
#      69     output_readout = self.readout(output_core, data_key=data_key)
#      70     return output_readout
#
# File ~/.local/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/open-retina/openretina/modules/core/transformer_core.py:141, in TransformerCoreWrapper.forward(self, input_)
#     139 # Tokenize input
#     140 pad_input = self.pad(input_)
# --> 141 embeddings, TP, SP = self.tokenizer(pad_input)
#     142 # embeddings shape: (B, TP, SP, Demb)
#     143
#     144 # Apply spatiotemporal transformer
#     145 output = self.transformer(embeddings, TP, SP)
#
# File ~/.local/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/open-retina/openretina/models/new_tokenizer.py:75, in VideoTokenizer.forward(self, x)
#      72     clip = clip.unfold(4, self.patch_size[1], self.spatial_stride)  # dim=W
#      73     # clip shape: (B, C, tp, n_h, n_w, ph, pw)
# ---> 75     clip = clip.contiguous().view(
#      76         B, C, self.temporal_patch_size,
#      77         num_patches_h, num_patches_w,
#      78         self.patch_size[0], self.patch_size[1]
#      79     )
#      80     patches.append(clip)
#      82 # Stack along temporal patches
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 170.00 MiB. GPU 0 has a total capacity of 10.75 GiB of which 107.62 MiB is free. Including non-PyTorch memory, this process has 10.64 GiB memory in use. Of the allocated memory 10.39 GiB is allocated by PyTorch, and 78.94 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# # Evaluation

# %% [markdown]
# Once the model is done training, we can turn to evaluation.
#
# First, let's still use the trainer to see the poisson and correlation performance on each of the dataloaders.

# %%
test_loader = ShortCycler(dataloaders["test"])
trainer.test(model, dataloaders=[train_loader, val_loader, test_loader], ckpt_path="best")

# %% [markdown]
# We can also look at further evals, like the fraction of explainable variance explained for an example session.

# %%
# Let's pick an example session
example_session = list(final_responses.keys())[0]

# Extract responses by trial:
responses_by_trial = final_responses[example_session].test_by_trial

responses_by_trial.shape
# Out:
# (80, 750, 3)

# %%
# Get the test movie for that session:
test_movie = dataloaders["test"][example_session].dataset.movies

# Pass it through the model: move to gpu and add batch dimension
with torch.no_grad():
    model_predictions = model.forward(test_movie.to(model.device).unsqueeze(0), data_key=example_session)

model_predictions.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Get the test movie for that session:
# ----> 2 test_movie = dataloaders["test"][example_session].dataset.movies
#       4 # Pass it through the model: move to gpu and add batch dimension
#       5 with torch.no_grad():
#
# NameError: name 'dataloaders' is not defined

# %%
help(feve)

# %%
# We need to reshape the predictions and responses by trial to match what the function expects

feve_score = feve(
    rearrange(responses_by_trial, "neurons time trials -> time trials neurons")[20:],
    model_predictions.squeeze(0).cpu().numpy(),
)

print(f"Average FEVe score for session {example_session}: {feve_score.mean():.2f}")

# %% [markdown]
# Finally, we can plot an example neuron's predictions and its ground truth response.

# %%
neuron_idx = 4
session_idx = 0


example_session = list(final_responses.keys())[session_idx]

test_sample = next(iter(dataloaders["test"][example_session]))
responses_by_trial = final_responses[example_session].test_by_trial
mean_test_responses = final_responses[example_session].test_response

input_samples = test_sample.inputs
targets = test_sample.targets

model.eval()
model.cpu()

with torch.no_grad():
    reconstructions = model(input_samples.cpu(), example_session)
reconstructions = reconstructions.cpu().numpy().squeeze()

feve_score = feve(
    rearrange(responses_by_trial, "neurons time trials -> time trials neurons")[20:],
    model_predictions.squeeze(0).cpu().numpy(),
)

correlations = correlation_numpy(mean_test_responses.T[20:], model_predictions.squeeze(0).cpu().numpy(), axis=0)


targets = targets.cpu().numpy().squeeze()
window = 750
plt.figure(figsize=(10, 5))
plt.plot(np.arange(0, window), targets[:window, neuron_idx], label="target")
plt.plot(np.arange(20, window), reconstructions[:window, neuron_idx], label="prediction")
plt.suptitle(f"Neuron {neuron_idx} - FEVE: {feve_score[neuron_idx]:.2f} - Correlation: {correlations[neuron_idx]:.2f}")

plt.legend()
sns.despine()

# %% [markdown]
# ---
